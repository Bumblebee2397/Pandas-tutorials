# %% [markdown]
# # Part 4: Filtering - Using Conditionals to Filter Rows and Columns

# %%
# Load data
import pandas as pd
path = "C:/Users/Dell/Desktop/ML Specialization/My Work - Post COVID/Pandas tutorials - Corey Schafer/developer_survey_2019/survey_results_public.csv"
df = pd.read_csv(path)

# %%
# Take a look at the data
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
# We can check how many people code as a hobby using filters
filt = (df['Hobbyist'] == 'Yes')

# %%
# On applying the filter we see that we only get the rows with a "Yes" for "Hobbyist"
df[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 7               8                        I code primarily as a hobby      Yes
# ...           ...                                                ...      ...
# 88872       87739                                                NaN      Yes
# 88875       88182                                                NaN      Yes
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
# ...

# %%
# We get the same results with df.loc as well
df.loc[filt] # When we pass filt as the first argument we are basically saying to pluck out all rows from the dataset that have a "Yes"
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 7               8                        I code primarily as a hobby      Yes
# ...           ...                                                ...      ...
# 88872       87739                                                NaN      Yes
# 88875       88182                                                NaN      Yes
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
# ...

# %%
# This can pluck out one/more than one columns subject to our filter condition
df.loc[filt, 'Country']
# Out:
# 0        United Kingdom
# 2              Thailand
# 4               Ukraine
# 5                Canada
# 7                 India
#               ...
# 88872    Czech Republic
# 88875          Pakistan
# 88877     United States
# 88878            Canada
# 88882             Spain
# Name: Country, Length: 71257, dtype: object

# %%
# NOTE we can't use the keywords 'and' & 'or'. We have to use '&' and '|' respectively
filt_hobby_country = (df["Hobbyist"] == 'Yes') & (df["Country"] == 'India')
df.loc[filt_hobby_country]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
# Set option to display all columns in the data
pd.set_option('display.max_columns', 85)

# %%
# Have a look at the data
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# Constructing a filter with a salary floor and country restriction
filt_salary = (df['ConvertedComp'] > 70000) & filt_hobby_country
df.loc[filt_salary, ['WorkRemote', 'WorkWeekHrs']]
# Out:
#                              WorkRemote  WorkWeekHrs
# 82     Less than once per month / Never         45.0
# 372               A few days each month         50.0
# 2871   Less than once per month / Never         45.0
# 3505              A few days each month         35.0
# 5396   Less than once per month / Never         72.0
# ...                                 ...          ...
# 86013                  It's complicated         45.0
# 86636             A few days each month         50.0
# 86764  Less than once per month / Never         40.0
# 88065  Less than once per month / Never         40.0
# 88217             A few days each month         50.0
#
# [203 rows x 2 columns]

# %%
# We also check within this limited set of people whether they know certain languages

filt_lang = filt_salary & df['LanguageWorkedWith'].str.contains('Java', na=False) & df['LanguageWorkedWith'].str.contains('Python', na=False) & df['LanguageWorkedWith'].str.contains('C', na=False)
df.loc[filt_lang]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 2871         2884                     I am a developer by profession      Yes
# 3505         3520                     I am a developer by profession      Yes
# 6823         6852                     I am a developer by profession      Yes
# 7041         7070                     I am a developer by profession      Yes
# 8670         8708                     I am a developer by profession      Yes
# 9488         9528                     I am a developer by profession      Yes
# 12558       12616                     I am a developer by profession      Yes
# 13984       14049                     I am a developer by profession      Yes
# 15569       15652                     I am a developer by profession      Yes
# 16703       16793                     I am a developer by profession      Yes
# 17343       17436                     I am a developer by profession      Yes
# ...
